# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 3] Descriptor Calculation and Dataset Preparation**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 3**, we will be calculating molecular descriptors that are essentially quantitative description of the compounds in the dataset. Finally, we will be preparing this into a dataset for subsequent model building in Part 4.
#
# ---

# %% [markdown]
# ## **Download PaDEL-Descriptor**

# %%
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Out:
# --2025-12-15 17:18:06--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-12-15 17:18:07 ERROR 404: Not Found.
#
# --2025-12-15 17:18:07--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-12-15 17:18:08 ERROR 404: Not Found.

# %%
! unzip padel.zip
# Out:
# unzip:  cannot find or open padel.zip, padel.zip.zip or padel.zip.ZIP.

# %% [markdown]
# ## **Load bioactivity data**

# %% [markdown]
# Download the curated ChEMBL bioactivity data that has been pre-processed from Parts 1 and 2 of this Bioinformatics Project series. Here we will be using the **bioactivity_data_3class_pIC50.csv** file that essentially contain the pIC50 values that we will be using for building a regression model.

# %%
! wget https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv
# Out:
# --2025-12-15 17:18:08--  https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 655414 (640K) [text/plain]
# Saving to: ‘acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv.1’
#
# acetylcholinesteras 100%[===================>] 640.05K  --.-KB/s    in 0.07s
#
# 2025-12-15 17:18:08 (9.11 MB/s) - ‘acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv.1’ saved [655414/655414]

# %%
import pandas as pd

# %%
df3 = pd.read_csv('acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv')

# %%
df3
# Out:
#     Unnamed: 0 molecule_chembl_id  \
# 0            0       CHEMBL463210
# 1            1      CHEMBL2252723
# 2            2      CHEMBL2252722
# 3            3      CHEMBL2252721
# 4            4      CHEMBL2252851
# 5            5      CHEMBL2252850
# 6            6      CHEMBL2252849
# 7            7      CHEMBL2252848
# 8            8      CHEMBL2252847
# 9            9      CHEMBL2252846
# 10          10      CHEMBL2252845
# 11          11      CHEMBL2252844
# 12          12      CHEMBL2252843
# 13          13      CHEMBL2252842
# 14          14      CHEMBL2252841
# 15          15      CHEMBL2252840
# 16          16      CHEMBL2252724
# 17          17      CHEMBL1232328
#
#                                canonical_smiles         class       MW  \
# 0              CCOP(=S)(OCC)Oc1nc(Cl)c(Cl)cc1Cl  intermediate  350.591
# 1   CCOP(=O)(OCC)SCCCCCCCCCCN1C(=O)c2ccccc2C1=O      inactive  455.557
# 2    CCOP(=O)(OCC)SCCCCCCCCCN1C(=O)c2ccccc2C1=O      inactive  441.530
# 3     CCOP(=O)(OCC)SCCCCCCCCN1C(=O)c2ccccc2C1=O  intermediate  427.503
# 4      CCOP(=O)(OCC)SCCCCCCCN1C(=O)c2ccccc2C1=O  intermediate  413.476
# 5       CCOP(=O)(OCC)SCCCCCCN1C(=O)c2ccccc2C1=O  intermediate  399.449
# 6        CCOP(=O)(OCC)SCCCCCN1C(=O)c2ccccc2C1=O      inactive  385.422
# 7         CCOP(=O)(OCC)SCCCCN1C(=O)c2ccccc2C1=O  intermediate  371.395
# 8          CCOP(=O)(OCC)SCCCN1C(=O)c2ccccc2C1=O  intermediate  357.368
# 9        CCOP(=O)(OCC)SCCCCCCCCCCSP(=O)(OCC)OCC  intermediate  478.594
# 10        CCOP(=O)(OCC)SCCCCCCCCCSP(=O)(OCC)OCC  intermediate  464.567
# 11         CCOP(=O)(OCC)SCCCCCCCCSP(=O)(OCC)OCC  intermediate  450.540
# 12          CCOP(=O)(OCC)SCCCCCCCSP(=O)(OCC)OCC      inactive  436.513
# 13           CCOP(=O)(OCC)SCCCCCCSP(=O)(OCC)OCC        active  422.486
# 14            CCOP(=O)(OCC)SCCCCCSP(=O)(OCC)OCC      inactive  408.459
# 15             CCOP(=O)(OCC)SCCCCSP(=O)(OCC)OCC  intermediate  394.432
# 16              CCOP(=O)(OCC)SCCCSP(=O)(OCC)OCC  intermediate  380.405
# 17                               CCOP(O)(=S)OCC      inactive  170.170
#
#       LogP  NumHDonors  NumHAcceptors     pIC50
# 0   4.7181         0.0            5.0  5.737549
# 1   6.3177         0.0            6.0  3.947999
# 2   5.9276         0.0            6.0  4.425969
# 3   5.5375         0.0            6.0  5.346787
# 4   5.1474         0.0            6.0  5.735182
# 5   4.7573         0.0            6.0  5.419075
# 6   4.3672         0.0            6.0  4.908685
# 7   3.9771         0.0            6.0  5.003488
# 8   3.5870         0.0            6.0  5.081445
# 9   7.9358         0.0            8.0  5.754487
# 10  7.5457         0.0            8.0  5.844664
# 11  7.1556         0.0            8.0  5.315155
# 12  6.7655         0.0            8.0  4.991400
# 13  6.3754         0.0            8.0  6.060481
# 14  5.9853         0.0            8.0  4.908685
# 15  5.5952         0.0            8.0  5.093126
# 16  5.2051         0.0            8.0  5.785156
# 17  1.2762         1.0            3.0  1.397940

# %%
selection = ['canonical_smiles','molecule_chembl_id']
df3_selection = df3[selection]
df3_selection.to_csv('molecule.smi', sep='\t', index=False, header=False)

# %%
! cat molecule.smi | head -5
# Out:
# CCOP(=S)(OCC)Oc1nc(Cl)c(Cl)cc1Cl	CHEMBL463210
# CCOP(=O)(OCC)SCCCCCCCCCCN1C(=O)c2ccccc2C1=O	CHEMBL2252723
# CCOP(=O)(OCC)SCCCCCCCCCN1C(=O)c2ccccc2C1=O	CHEMBL2252722
# CCOP(=O)(OCC)SCCCCCCCCN1C(=O)c2ccccc2C1=O	CHEMBL2252721
# CCOP(=O)(OCC)SCCCCCCCN1C(=O)c2ccccc2C1=O	CHEMBL2252851

# %%
! cat molecule.smi | wc -l
# Out:
# 18

# %% [markdown]
# ## **Calculate fingerprint descriptors**

# %% [markdown]
# ### **Calculate PaDEL descriptors**

# %%
! cat padel.sh
# Out:
# cat: padel.sh: No such file or directory

# %%
! bash padel.sh
# Out:
# bash: padel.sh: No such file or directory

# %%
! ls -l
# Out:
# total 101572
# -rw-r--r-- 1 leeva leeva      9828 Dec 15 17:16 acetylcholinesterase_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 leeva leeva      1093 Dec 15 17:16 acetylcholinesterase_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 leeva leeva      1303 Dec 15 17:16 acetylcholinesterase_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 leeva rayhan   385924 Dec 15 17:07 acetylcholinesterase_03_bioactivity_data_curated.csv.1
# -rw-r--r-- 1 leeva rayhan   385924 Dec 15 17:16 acetylcholinesterase_03_bioactivity_data_curated.csv.2
# -rw-r--r-- 1 leeva leeva      2345 Dec 15 17:16 acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv
# -rw-r--r-- 1 leeva rayhan   655414 Dec 15 17:18 acetylcholinesterase_04_bioactivity_data_3class_pIC50.csv.1
# -rw-r--r-- 1 leeva leeva       932 Dec 15 17:16 acetylcholinesterase_05_bioactivity_data_2class_pIC50.csv
# -rw-r--r-- 1 leeva leeva   8368605 Dec 13 19:09 acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# -rw-r--r-- 1 leeva leeva   6327445 Dec 13 19:09 acetylcholinesterase_07_bioactivity_data_2class_pIC50_pubchem_fp.csv
# -rw-r--r-- 1 leeva rayhan   874346 Dec 15 17:16 acetylcholinesterase.zip
# -rw-r--r-- 1 leeva rayhan   132107 Dec 15 17:17 CDD_ML_Part_1_Acetylcholinesterase_Bioactivity_Data_Concised.ipynb
# -rw-r--r-- 1 leeva rayhan   269168 Dec 15 17:15 CDD_ML_Part_2_Acetylcholinesterase_Exploratory_Data_Analysis.ipynb
# -rw-r--r-- 1 leeva rayhan    38205 Dec 15 17:15 CDD_ML_Part_3_Acetylcholinesterase_Descriptor_Dataset_Preparation.ipynb
# -rw-r--r-- 1 leeva rayhan   106730 Dec 15 17:15 CDD_ML_Part_4_Acetylcholinesterase_Regression_Random_Forest.ipynb
# -rw-r--r-- 1 leeva rayhan   528780 Dec 15 17:15 CDD_ML_Part_5_Acetylcholinesterase_Compare_Regressors.ipynb
# drwxr-xr-x 5 leeva rayhan     4096 Dec 15 17:14 first_repo
# -rw-r--r-- 1 leeva rayhan      119 Dec 15 17:16 mannwhitneyu_LogP.csv
# -rw-r--r-- 1 leeva rayhan      102 Dec 15 17:16 mannwhitneyu_MW.csv
# -rw-r--r-- 1 leeva rayhan      128 Dec 15 17:16 mannwhitneyu_NumHAcceptors.csv
# -rw-r--r-- 1 leeva rayhan      110 Dec 15 17:16 mannwhitneyu_NumHDonors.csv
# -rw-r--r-- 1 leeva rayhan      121 Dec 15 17:16 mannwhitneyu_pIC50.csv
# -rwxr-xr-x 1 leeva rayhan 85055499 Feb 13  2025 Miniconda3-py37_4.8.2-Linux-x86_64.sh
# -rw-r--r-- 1 leeva rayhan      907 Dec 15 17:18 molecule.smi
# -rw-r--r-- 1 leeva rayhan    14312 Dec 15 17:16 plot_bioactivity_class.pdf
# -rw-r--r-- 1 leeva rayhan    14601 Dec 15 17:16 plot_ic50.pdf
# -rw-r--r-- 1 leeva rayhan    13483 Dec 15 17:16 plot_LogP.pdf
# -rw-r--r-- 1 leeva rayhan    12693 Dec 15 17:16 plot_MW.pdf
# -rw-r--r-- 1 leeva rayhan    16820 Dec 15 17:16 plot_MW_vs_LogP.pdf
# -rw-r--r-- 1 leeva rayhan    14902 Dec 15 17:16 plot_NumHAcceptors.pdf
# -rw-r--r-- 1 leeva rayhan    14651 Dec 15 17:16 plot_NumHDonors.pdf
# -rw-r--r-- 1 leeva leeva        29 Dec 13 19:09 README.md
# -rw-r--r-- 1 leeva rayhan   666760 Dec 15 17:16 results.zip

# %% [markdown]
# ## **Preparing the X and Y Data Matrices**

# %% [markdown]
# ### **X data matrix**

# %%
df3_X = pd.read_csv('descriptors_output.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df3_X = pd.read_csv('descriptors_output.csv')
#
# File /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'descriptors_output.csv'

# %%
df3_X

# %%
df3_X = df3_X.drop(columns=['Name'])
df3_X

# %% [markdown]
# ## **Y variable**

# %% [markdown]
# ### **Convert IC50 to pIC50**

# %%
df3_Y = df3['pIC50']
df3_Y

# %% [markdown]
# ## **Combining X and Y variable**

# %%
dataset3 = pd.concat([df3_X,df3_Y], axis=1)
dataset3

# %%
dataset3.to_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv', index=False)

# %% [markdown]
# # **Let's download the CSV file to your local computer for the Part 3B (Model Building).**
