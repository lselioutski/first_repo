# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 5] Comparing Regressors**
#
# Chanin Nantasenamat
#
# ['Data Professor' YouTube channel](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life data science project that you can include in your data science portfolio. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In Part 5, we will be comparing several ML algorithms for build regression models of acetylcholinesterase inhibitors.

# %% [markdown]
# ## **1. Import libraries**

# %%
! pip install lazypredict
# Out:
# Requirement already satisfied: lazypredict in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (0.2.16)
# Requirement already satisfied: click in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from lazypredict) (8.3.1)
# Requirement already satisfied: scikit-learn in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from lazypredict) (1.7.2)
# Requirement already satisfied: pandas in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from lazypredict) (2.3.3)
# Requirement already satisfied: tqdm in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from lazypredict) (4.67.1)
# Requirement already satisfied: joblib in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from lazypredict) (1.5.2)
# Requirement already satisfied: lightgbm in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from lazypredict) (4.6.0)
# Requirement already satisfied: xgboost in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from lazypredict) (3.1.1)
# Requirement already satisfied: pytest-runner in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from lazypredict) (6.0.1)
# Requirement already satisfied: mlflow>=2.0.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from lazypredict) (3.6.0)
# Requirement already satisfied: mlflow-skinny==3.6.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict) (3.6.0)
# Requirement already satisfied: mlflow-tracing==3.6.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict) (3.6.0)
# Requirement already satisfied: Flask-CORS<7 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict) (6.0.1)
# Requirement already satisfied: Flask<4 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict) (1.17.2)
# Requirement already satisfied: cryptography<47,>=43.0.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict) (46.0.3)
# Requirement already satisfied: docker<8,>=4.0.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict) (7.1.0)
# Requirement already satisfied: graphene<4 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict) (23.0.0)
# Requirement already satisfied: huey<3,>=2.5.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict) (2.5.4)
# Requirement already satisfied: matplotlib<4 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict) (3.10.6)
# Requirement already satisfied: numpy<3 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict) (2.2.5)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict) (22.0.0)
# Requirement already satisfied: scipy<2 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict) (1.15.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow>=2.0.0->lazypredict) (2.0.43)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (6.2.2)
# Requirement already satisfied: cloudpickle<4 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (0.73.0)
# Requirement already satisfied: fastapi<1 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (0.121.3)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (1.38.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (1.38.0)
# Requirement already satisfied: packaging<26 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (6.33.1)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (2.12.4)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (1.2.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (4.15.0)
# Requirement already satisfied: uvicorn<1 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (0.38.0)
# Requirement already satisfied: Mako in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow>=2.0.0->lazypredict) (1.3.10)
# Requirement already satisfied: tomli in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow>=2.0.0->lazypredict) (2.2.1)
# Requirement already satisfied: cffi>=2.0.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from cryptography<47,>=43.0.0->mlflow>=2.0.0->lazypredict) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (2.43.0)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from docker<8,>=4.0.0->mlflow>=2.0.0->lazypredict) (2.5.0)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from fastapi<1->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from fastapi<1->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (0.0.4)
# Requirement already satisfied: blinker>=1.9.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from Flask<4->mlflow>=2.0.0->lazypredict) (3.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from graphene<4->mlflow>=2.0.0->lazypredict) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from graphene<4->mlflow>=2.0.0->lazypredict) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from graphene<4->mlflow>=2.0.0->lazypredict) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (1.4.8)
# Requirement already satisfied: pillow>=8 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from matplotlib<4->mlflow>=2.0.0->lazypredict) (3.2.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (0.59b0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from pandas->lazypredict) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from pandas->lazypredict) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (0.4.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow>=2.0.0->lazypredict) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (2025.11.12)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (0.6.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from scikit-learn->lazypredict) (3.5.0)
# Requirement already satisfied: greenlet>=1 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from sqlalchemy<3,>=1.4.0->mlflow>=2.0.0->lazypredict) (3.2.4)
# Requirement already satisfied: anyio<5,>=3.6.2 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (4.10.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (1.2.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (1.3.0)
# Requirement already satisfied: h11>=0.8 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from uvicorn<1->mlflow-skinny==3.6.0->mlflow>=2.0.0->lazypredict) (0.16.0)
# Requirement already satisfied: pycparser in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow>=2.0.0->lazypredict) (2.23)
# Requirement already satisfied: nvidia-nccl-cu12 in /opt/anaconda/envs/bioinfo/lib/python3.10/site-packages (from xgboost->lazypredict) (2.28.9)

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor
import tqdm
tqdm.notebook.tqdm = tqdm.tqdm

# %% [markdown]
# ## **2. Load the data set**

# %%
! wget https://github.com/dataprofessor/data/raw/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Out:
# --2025-12-15 17:18:54--  https://github.com/dataprofessor/data/raw/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv [following]
# --2025-12-15 17:18:55--  https://raw.githubusercontent.com/dataprofessor/data/master/acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8363909 (8.0M) [text/plain]
# Saving to: ‘acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv.2’
#
# acetylcholinesteras 100%[===================>]   7.98M  41.8MB/s    in 0.2s
#
# 2025-12-15 17:18:55 (41.8 MB/s) - ‘acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv.2’ saved [8363909/8363909]

# %%
df = pd.read_csv('acetylcholinesterase_06_bioactivity_data_3class_pIC50_pubchem_fp.csv')

# %%
X = df.drop('pIC50', axis=1)
Y = df.pIC50

# %% [markdown]
# ## **3. Data pre-processing**

# %%
# Examine X dimension
X.shape
# Out:
# (4695, 881)

# %%
# Remove low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)
X.shape
# Out:
# (4695, 137)

# %%
# Perform data splitting using 80/20 ratio
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# ## **4. Compare ML algorithms**

# %%
# Defines and builds the lazyclassifier
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001545 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 411
# [LightGBM] [Info] Number of data points in the train set: 3756, number of used features: 137
# [LightGBM] [Info] Start training from score 5.814494
# 'tuple' object has no attribute '__name__'
# Invalid Regressor(s)
#   0%|          | 0/42 [00:00<?, ?it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000836 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 411
# [LightGBM] [Info] Number of data points in the train set: 3756, number of used features: 137
# [LightGBM] [Info] Start training from score 5.814494

# %%
# Performance table of the training set (80% subset)
predictions_train
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreeRegressor                           0.86       0.86  0.57        0.16
# DecisionTreeRegressor                        0.86       0.86  0.57        0.13
# ExtraTreesRegressor                          0.86       0.86  0.57        5.40
# GaussianProcessRegressor                     0.86       0.86  0.57        3.27
# RandomForestRegressor                        0.82       0.83  0.64        3.50
# XGBRegressor                                 0.82       0.83  0.65        2.59
# BaggingRegressor                             0.80       0.81  0.67        0.41
# MLPRegressor                                 0.76       0.77  0.75        3.28
# HistGradientBoostingRegressor                0.67       0.69  0.87        0.46
# LGBMRegressor                                0.65       0.67  0.90        0.22
# KNeighborsRegressor                          0.63       0.65  0.92        0.12
# SVR                                          0.56       0.58  1.01        1.94
# NuSVR                                        0.55       0.57  1.02        1.38
# GradientBoostingRegressor                    0.44       0.46  1.14        1.29
# TransformedTargetRegressor                   0.31       0.33  1.27        0.09
# LinearRegression                             0.31       0.33  1.27        0.03
# Ridge                                        0.31       0.33  1.27        0.06
# LassoCV                                      0.30       0.33  1.27        1.49
# ElasticNetCV                                 0.30       0.33  1.27        1.50
# RidgeCV                                      0.30       0.33  1.27        0.11
# SGDRegressor                                 0.30       0.32  1.28        0.10
# BayesianRidge                                0.29       0.32  1.28        0.11
# HuberRegressor                               0.29       0.31  1.29        0.14
# LassoLarsIC                                  0.29       0.31  1.29        0.05
# LassoLarsCV                                  0.29       0.31  1.29        0.15
# LinearSVR                                    0.27       0.30  1.30        0.43
# PoissonRegressor                             0.25       0.28  1.32        0.04
# AdaBoostRegressor                            0.20       0.23  1.36        0.59
# OrthogonalMatchingPursuitCV                  0.20       0.23  1.37        0.15
# OrthogonalMatchingPursuit                    0.20       0.23  1.37        0.05
# TweedieRegressor                             0.19       0.22  1.37        0.10
# GammaRegressor                               0.19       0.22  1.37        0.10
# LarsCV                                       0.13       0.16  1.42        0.17
# ElasticNet                                  -0.04       0.00  1.55        0.03
# DummyRegressor                              -0.04       0.00  1.55        0.03
# LassoLars                                   -0.04       0.00  1.55        0.04
# Lasso                                       -0.04       0.00  1.55        0.03
# QuantileRegressor                           -0.05      -0.01  1.56        1.00
# PassiveAggressiveRegressor                  -0.17      -0.13  1.65        0.05
# RANSACRegressor                             -1.30      -1.21  2.31        0.35
# KernelRidge                                -14.25     -13.70  5.95        0.54
# Lars                                       -14.38     -13.82  5.98        0.05

# %%
# Performance table of the test set (20% subset)
predictions_test
# Out:
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# HistGradientBoostingRegressor                0.46       0.54  1.06        0.62
# RandomForestRegressor                        0.44       0.52  1.08        3.51
# LGBMRegressor                                0.44       0.52  1.08        0.14
# XGBRegressor                                 0.44       0.52  1.08        0.66
# BaggingRegressor                             0.41       0.49  1.11        0.41
# NuSVR                                        0.39       0.48  1.12        0.80
# SVR                                          0.39       0.48  1.12        0.97
# KNeighborsRegressor                          0.38       0.47  1.13        0.04
# MLPRegressor                                 0.36       0.45  1.15        2.50
# GradientBoostingRegressor                    0.33       0.42  1.18        1.23
# ExtraTreesRegressor                          0.22       0.34  1.27        5.53
# DecisionTreeRegressor                        0.20       0.32  1.28        0.15
# Ridge                                        0.20       0.32  1.28        0.04
# LinearRegression                             0.20       0.32  1.28        0.03
# TransformedTargetRegressor                   0.20       0.32  1.28        0.06
# RidgeCV                                      0.20       0.32  1.28        0.04
# ElasticNetCV                                 0.20       0.32  1.28        1.41
# LassoCV                                      0.20       0.32  1.28        1.52
# ExtraTreeRegressor                           0.20       0.32  1.29        0.10
# SGDRegressor                                 0.19       0.31  1.29        0.06
# BayesianRidge                                0.19       0.31  1.29        0.07
# LassoLarsCV                                  0.19       0.31  1.29        0.13
# LassoLarsIC                                  0.19       0.31  1.29        0.05
# HuberRegressor                               0.19       0.31  1.29        0.13
# LinearSVR                                    0.16       0.28  1.32        0.39
# PoissonRegressor                             0.16       0.28  1.32        0.03
# OrthogonalMatchingPursuit                    0.11       0.24  1.36        0.03
# OrthogonalMatchingPursuitCV                  0.11       0.24  1.36        0.09
# GammaRegressor                               0.08       0.22  1.37        0.05
# TweedieRegressor                             0.08       0.22  1.38        0.07
# AdaBoostRegressor                            0.07       0.21  1.38        0.52
# LarsCV                                       0.02       0.16  1.42        0.15
# DummyRegressor                              -0.17      -0.00  1.55        0.02
# ElasticNet                                  -0.17      -0.00  1.55        0.03
# LassoLars                                   -0.17      -0.00  1.55        0.03
# Lasso                                       -0.17      -0.00  1.55        0.03
# QuantileRegressor                           -0.19      -0.02  1.57        0.94
# PassiveAggressiveRegressor                  -0.42      -0.22  1.71        0.06
# RANSACRegressor                             -1.56      -1.19  2.30        0.30
# GaussianProcessRegressor                    -6.02      -4.99  3.80        2.23
# KernelRidge                                -16.36     -13.82  5.98        0.49
# Lars                                       -23.48     -19.91  7.10        0.05

# %% [markdown]
# ## **5. Data visualization of model performance**

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="Time Taken", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
